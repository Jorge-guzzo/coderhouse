# %% [markdown]
# <a href="https://colab.research.google.com/github/Jorge-guzzo/coderhouse/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests

import requests
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects

import json
import pandas as pd
import time

import os
from configparser import ConfigParser

from pathlib import Path

config = ConfigParser()

url = 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
endpoint = {
"data": [
{
"cover": "https://academy-public.coinmarketcap.com/optimized-uploads/0aec0502868046419ceace229f92601f.gif",
"assets": [
{
"id": 1027,
"name": "Ethereum",
"symbol": "ETH",
"slug": "ethereum"
}
],
"created_at": "2021-05-05T00:00:00Z",
"released_at": "2021-05-05T00:00:00Z",
"title": "Article Title",
"subtitle": "Article Subtitle",
"type": "alexandria",
"source_name": "Connor Sephton",
"source_url": "https://coinmarketcap.com/alexandria/article/coinmarketcap-news-august-9-u-s-comes-for-tornado-cash"
}
],
"status": {
"timestamp": "2018-06-02T22:51:28.209Z",
"error_code": 0,
"error_message": "",
"elapsed": 10,
"credit_count": 1
}}
CMC_PRO_API_KEY = '51cf7543-d1ab-4b87-be0c-171773c1db67'
params = {
  'start':'1',
  'limit':'50',
  'convert':'ARS'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'b54bcf4d-1bca-4e8e-9a24-22ff2c3d462c',
}

session = Session()
session.headers.update(headers)

resp = requests.get(url,params=params,headers=headers)

print(CMC_PRO_API_KEY)

data = resp.json()

if resp.status_code == 200:
  resp_json = resp.json()
else:
    print("Error al hacer la solicitud:", resp.status_code)

print(resp.json)

resp.json()["data"]

print(resp_json)
print(resp_json.keys())

stations_data = resp_json["data"]
df_stations_new = pd.DataFrame(stations_data)
df_stations_new.head(10)
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.11.17)
# 51cf7543-d1ab-4b87-be0c-171773c1db67
# <bound method Response.json of <Response [200]>>
# {'status': {'timestamp': '2023-12-18T08:33:05.166Z', 'error_code': 0, 'error_message': None, 'elapsed': 1, 'credit_count': 1, 'notice': None}, 'data': [{'id': 9415, 'name': 'vqqfbfbqpe', 'symbol': 'e71zbbll3il', 'slug': 'xib6kyf0o9', 'cmc_rank': 2796, 'num_market_pairs': 1713, 'circulating_supply': 2480, 'total_supply': 4927, 'max_supply': 6631, 'infinite_supply': None, 'last_updated': '2023-12-18T08:33:05.166Z', 'date_added': '2023-12-18T08:33:05.166Z', 'tags': ['v08w9bwu0a', 'ibb7izo369m', 'pu9tdze73f', 'tv5555hw4la', 'nbkeknb85g', 'rk2nhcaqvza', '344h6l11g5y', 'damwy1c4crv', 'obg68wlsss', 'soffrx1szb'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'ARS': {'price': 0.6609812743049699, 'volume_24h': 298, 'volume_change_24h': 0.43387624702144123, 'percent_change_1h': 0.7067061496913045, 'percent_change_24h': 0.9639845105119753, 'percent_change_7d': 0.6219135360308417, 'market_cap': 0.8711731093772976, 'market_cap_dominance': 5772, 'fully_diluted_market_cap': 0.2891343863457685, 'last_updated': '2023-12-18T08:33:05.166Z'}}}, {'id': 2089, 'name': 'wmgxy24dyd', 'symbol': 'ir5fcsvy7n', 'slug': 'tz3np34cvjq', 'cmc_rank': 3334, 'num_market_pairs': 2074, 'circulating_supply': 6567, 'total_supply': 1542, 'max_supply': 2666, 'infinite_supply': None, 'last_updated': '2023-12-18T08:33:05.166Z', 'date_added': '2023-12-18T08:33:05.166Z', 'tags': ['korufzo31q', 'lmk03jcncz7', '1g4ksnx36xt', '06fvxhf74hxf', 'kziohj65xgj', 'fln7rnc30x5', 'ylh6rdm9xn', 'wadeyyknpy', 'ph0cy6y8kp', 'mzgfb1kl78'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'ARS': {'price': 0.2257383091346976, 'volume_24h': 6672, 'volume_change_24h': 0.8664478430484837, 'percent_change_1h': 0.046288071597883285, 'percent_change_24h': 0.06159268032010945, 'percent_change_7d': 0.4008898002752339, 'market_cap': 0.9210388076848577, 'market_cap_dominance': 4429, 'fully_diluted_market_cap': 0.3693456371077717, 'last_updated': '2023-12-18T08:33:05.166Z'}}}, {'id': 1974, 'name': '2ze6z6210w2', 'symbol': 'tbmfhrg9tg9', 'slug': 'cx9zxdb57ls', 'cmc_rank': 8592, 'num_market_pairs': 5611, 'circulating_supply': 4164, 'total_supply': 1253, 'max_supply': 8760, 'infinite_supply': None, 'last_updated': '2023-12-18T08:33:05.166Z', 'date_added': '2023-12-18T08:33:05.166Z', 'tags': ['6m941qo0ms6', 'woqkpa5jvo', 'n7o9lsmo4df', 'cxtf40xcvsb', 'vn6bdtk0s0o', 'jmiye4ou0i9', 'xfas7arje3s', 'kpe5cq7lfi', 'xzl2nt6xim', 'icoox27vtza'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'ARS': {'price': 0.7227240550402239, 'volume_24h': 7171, 'volume_change_24h': 0.24883379839795006, 'percent_change_1h': 0.4184983833831426, 'percent_change_24h': 0.649526709149399, 'percent_change_7d': 0.7948112516268302, 'market_cap': 0.04869084119962608, 'market_cap_dominance': 7324, 'fully_diluted_market_cap': 0.8692809834599105, 'last_updated': '2023-12-18T08:33:05.166Z'}}}, {'id': 3088, 'name': '3vlu5e1bfdw', 'symbol': 'frcsqxp2zn9', 'slug': 'ybxyxsfgfil', 'cmc_rank': 9125, 'num_market_pairs': 9775, 'circulating_supply': 5237, 'total_supply': 1003, 'max_supply': 4382, 'infinite_supply': None, 'last_updated': '2023-12-18T08:33:05.166Z', 'date_added': '2023-12-18T08:33:05.166Z', 'tags': ['bmg8b2u9xgp', 'nmbz256zrc', 'ww7ft6xkuyb', '8jnz7p9zb6', 'qytv67urlxo', 'n24q1vkbg8s', 'a2q39yino9u', 'ta8g8uk7mm', 'nhx353u08pa', 'lpr5hx3tl5b'], 'platform': None, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'quote': {'ARS': {'price': 0.10840143575453998, 'volume_24h': 1055, 'volume_change_24h': 0.4192426705579335, 'percent_change_1h': 0.5624676941311872, 'percent_change_24h': 0.22086237191343283, 'percent_change_7d': 0.5445580762461584, 'market_cap': 0.9956304193542318, 'market_cap_dominance': 9774, 'fully_diluted_market_cap': 0.9610563455479038, 'last_updated': '2023-12-18T08:33:05.166Z'}}}, {'id': 9660, 'name': 's38x4rrtleh', 'symbol': ...
# dict_keys(['status', 'data'])
#      id         name       symbol          slug  cmc_rank  num_market_pairs  \
# 0  9415   vqqfbfbqpe  e71zbbll3il    xib6kyf0o9      2796              1713
# 1  2089   wmgxy24dyd   ir5fcsvy7n   tz3np34cvjq      3334              2074
# 2  1974  2ze6z6210w2  tbmfhrg9tg9   cx9zxdb57ls      8592              5611
# 3  3088  3vlu5e1bfdw  frcsqxp2zn9   ybxyxsfgfil      9125              9775
# 4  9660  s38x4rrtleh  682851j0u4s   5chlxdxdsen      1648              2954
# 5  8269   tav2cz6jfd  y40hlzutend   9y0i74b5erc      2529              6474
# 6  3767  s7ltgqfi8sk   p0civtcrzq    v0keui0ku3      9378              7884
# 7  6687   vfktoxwofv  7o7he4r56px   0rpj362ay5b      7956              3681
# 8  3661  rey6hr10ahr  8h8ni7l2aq5    rzqzau7qkf      9522              4660
# 9  4411  acv8p64hrkh  4jg1j6c15x9  158skbckcd8i      6593              5095
#
#    circulating_supply  total_supply  max_supply infinite_supply  \
# 0                2480          4927        6631            None
# 1                6567          1542        2666            None
# 2                4164          1253        8760            None
# 3                5237          1003        4382            None
# 4                6282           781        7571            None
# 5                2238           256         860            None
# 6                9982          7991        4206            None
# 7                8540          2263        4215            None
# 8                5154          8108        3506            None
# 9                3016          7795        4591            None
#
#                last_updated                date_added  \
# 0  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 1  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 2  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 3  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 4  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 5  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 6  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 7  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 8  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
# 9  2023-12-18T08:33:05.166Z  2023-12-18T08:33:05.166Z
#
#                                                 tags platform  \
# 0  [v08w9bwu0a, ibb7izo369m, pu9tdze73f, tv5555hw...     None
# 1  [korufzo31q, lmk03jcncz7, 1g4ksnx36xt, 06fvxhf...     None
# 2  941qo0ms6, woqkpa5jvo, n7o9lsmo4df, cxtf40x...     None
# 3  [bmg8b2u9xgp, nmbz256zrc, ww7ft6xkuyb, 8jnz7p9...     None
# 4  [v233y7kqfp, 62na8t0bmje, rfld8ggzos, g9vgiczg...     None
# 5  [qe4dcncekg, zu2c6qyt0xe, eil9wv1uh7, 0pth9gku...     None
# 6  [udbqmtkfb2n, abgxs3mepy, k6nez8qkozi, it1q426...     None
# 7  [i6n7h78710j, cmn4wjzydp5, qbrvv7hhj7o, 1umndp...     None
# 8  [1dt5j6umza7, 6f27g3e1d8i, 9lerdclsmw, atxl7dd...     None
# 9  [v01t1qyk1o9, zfl1meheprd, i2s9lnsz8vl, 0xp4r7...     None
#
#   self_reported_circulating_supply self_reported_market_cap  \
# 0                             None                     None
# 1                             None                     None
# 2                             None                     None
# 3                             None                     None
# 4                             None                     None
# 5                             None                     None
# 6                             None                     None
# 7                             None                     None
# 8                             None                     None
# 9                             None                     None
#
#                                                quote
# 0  {'ARS': {'price': 0.6609812743049699, 'volume_...
# 1  {'ARS': {'price': 0.2257383091346976, 'volume_...
# 2  {'ARS': {'price': 0.7227240550402239, 'volume_...
# 3  {'ARS': {'price': 0.10840143575453998, 'volume...
# 4  {'ARS': {'price': 0.11866430407503614, 'volume...
# 5  {'ARS': {'price': 0.397215432031673, 'volume_2...
# 6  {'ARS': {'price': 0.9929073391243697, 'volume_...
# 7  {'ARS': {'price': 0.09210890878763478, 'volume...
# 8  {'ARS': {'price': 0.5206178783953481, 'volume_...
# 9  {'ARS': {'price': 0.7700641605135345, 'volume_...
